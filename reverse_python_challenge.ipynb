# %%
# Python offers several ways to reverse a String. This is a classic thing
# that lots of people want to do.

# %%
my_str = input('Enter a string: ')
# Out:
# Enter a string: Butt hole

# %%
temp = ''

# %%
for char in my_str:
    temp = char + temp
print(temp)
# Out:
# eloh ttuB
